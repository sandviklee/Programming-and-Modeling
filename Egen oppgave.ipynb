# %%
from pylab import * 

data = loadtxt('Rådata.csv', skiprows=1, delimiter=",")

tid = data[:,0]
akselerasjon = data[:,3]

plot(tid, akselerasjon)
show()

# %%
x = []

for i in akselerasjon:   
    if -0.11 < i < 0.1:
        x.append(i)
    skritt = len(x)
print("Antall skritt er", skritt)
# Out:
# Antall skritt er 64
